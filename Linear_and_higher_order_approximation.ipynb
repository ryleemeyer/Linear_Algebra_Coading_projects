# %% [markdown]
# <a href="https://colab.research.google.com/github/ryleemeyer/Linear_Algebra_Coading_projects/blob/main/Linear_and_higher_order_approximation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Approximating functions with derivatives
#
# Functions can be approximated in several different ways.
#
# A very simple way is to just choose some inputs that are spread out:
#
#  $$  x = 1 \hspace{1cm} x = 3 \hspace{1cm} x = 5 \hspace{1cm} x = 7 \hspace{1cm} x = 9 $$
#
# and then use the outputs that are associated with them:
#
# In the case of $y = \sqrt{x}$, the outputs would be
#
# $$ y = \sqrt{1} \hspace{1cm} y = \sqrt{3} \hspace{1cm} y = \sqrt{5} \hspace{1cm} y = \sqrt{7} \hspace{1cm} y = \sqrt{9}$$
#
# In this scenario, we'd choose the best output by just finding the a nearby input.  So, to approximate the function when $x = 8.2$, we'd estimate that the output is
#
# $$ \sqrt{8.2} \approx \sqrt{9} = 3 $$
#
# In this activity, we'll explore two better ways to approximate functions.
#
# Three quick notes:
#
#   1.  We'll be doing computations in Desmos.  It may be helpful to copy the Desmos URL into a new window and do the work there.
#
#   2.  You'll save screenshots into this worksheet.  On a mac, hold **Shift**, **Command**, and **3** together.  On a PC, hold the **Windows Logo Key**, **Shift**, and **S** key together.  Then, copy the image to your clipboard, and paste it into a new cell.
#
#   3.  Be sure to save your worksheet back out to your github account.

# %% [markdown]
# # Estimating Functions on Segments
#
# In this part of the activity, we'll appoximate the function
#
# $$ y = \sqrt{x}$$
#
# by using the best point, line, and then parabola on small segments.
#
# All of the code is written within Desmos.  You'll be asked to provide a screenshot showing:
#
#   1.  The approximation just with points (already provided).
#   2.  The approximation with just lines, using a first derivative
#   3.  The approximation with quadratics, using a second derivative
#   4.  [Optional] A cubic approximation for the entire segment $0 \le x \le 10$

# %%
DesmosURL = "https://www.desmos.com/calculator/ai65zhhipu"
#  Uncomment these lines to display here:
#from IPython.display import IFrame
#IFrame(src=DesmosURL, width=1200, height=575)

# %% [markdown]
# #  Approximation with a points:

# %% [markdown]
# << Paste the picture here >>![image.png](data:image/png;base64,...)

# %% [markdown]
# Approximation with lines:

# %% [markdown]
# << Paste the picture here >>![Screen Shot 2022-03-01 at 10.25.19 AM.png](data:image/png;base64,...)

# %% [markdown]
# Approximation with quadratics (using second derivatives)

# %% [markdown]
# << Paste the picture here >>![Screen Shot 2022-03-01 at 10.37.12 AM.png](data:image/png;base64,...)

# %% [markdown]
# [ Optional ]  Approximating with the cubic (using a third derivative )

# %% [markdown]
# ![Screen Shot 2022-03-01 at 10.40.54 AM.png](data:image/png;base64,...)<< Paste the picture here >>

# %% [markdown]
# << Paste the picture here  >>

# %% [markdown]
# # Approximating with just one interval
#
# In this part of the activity, we're going to approximate a function
#
# $$ y = sin(x)$$
#
# Our prior approach, breaking up the interval into several small segments, would work fine.  We'll use a different approach, one which uses more derivatives but fewer intervals.
#
# For this process, we'll need to find several derivatives.  We'll successively add them into the expression, generating:
#
#   1.  A linear approximation  (using a derivative)
#   2.  A quadratic approximation (using a 1st and 2nd derivative)
#   3.  A cubic approximation (using a 1st, 2nd, and 3rd derivative)
#   4.  A quartic, or 4th order, approximation
#   5.  A quintic (5th order) approximation
#
# Again, you'll provide screenshots of the graphs below.  For each graph, you'll also provide an interval over which the approximation works well for the function.

# %%
DesmosURL = "https://www.desmos.com/calculator/nvbgdvmbk1"
#  Uncomment these lines to display here:
#from IPython.display import IFrame
#IFrame(src=DesmosURL, width=1200, height=575)

# %% [markdown]
# Linear (1st order) approximation:
#
# Q:  When $a = 0$, how well does this approximate the $y = sin(x)$ function?  Give the interval.
#
# A:

# %% [markdown]
# << Paste the picture here >>![Screen Shot 2022-03-03 at 10.29.14 AM.png](data:image/png;base64,...)

# %% [markdown]
# Quadratic (2nd order) approximation
#
# Q:  When $a = 0$, how well does this approximate the $y = sin(x)$ function?  Give the interval.
#
# A:

# %% [markdown]
# ![Screen Shot 2022-03-03 at 10.29.52 AM.png](data:image/png;base64,...)<< Paste the picture here >>

# %% [markdown]
# Cubic (3rd order) approximation
#
# Q:  When $a = 0$, how well does this approximate the $y = sin(x)$ function?  Give the interval.
#
# A:

# %% [markdown]
# Quartic (4th order) approximation
#
# Q:  When $a = 0$, how well does this approximate the $y = sin(x)$ function?  Give the interval.
#
# A:

# %% [markdown]
# ![Screen Shot 2022-03-03 at 10.36.58 AM.png](data:image/png;base64,...)<< Paste the picture here >>

# %% [markdown]
# Quintic (5th order) approximation
#
# Q:  When $a = 0$, how well does this approximate the $y = sin(x)$ function?  Give the interval.
#
# A:

# %% [markdown]
# ![Screen Shot 2022-03-03 at 10.36.00 AM.png](data:image/png;base64,...)<< Paste the picture here >>

# %% [markdown]
# Challenge:  Keep expanding the approximation.  How far out can you get it?
#
# Q:  When $a = 0$, how well does this approximate the $y = sin(x)$ function?  Give the interval.
#
# A:

# %% [markdown]
# << Paste the picture here >>

# %% [markdown]
# # Summary
#
# Answer the following five questions on the attached packet.  They are included here for reference:
#
# 1.  What is an advantage of the first method, using several segments, compared to the second method, which uses several derivatives?
#
#
# 2.  What is an advantage of the second method, using several derivatives, compared to the first method, using several segments?
#
#
# 3.  Provide a scenario where you'd prefer to use the first method to approximate a function.
#
#
# 4.  Provide a scenario where you'd prefer to use the second method to approximate a function.
#
#
# 5.  What happened to the intervals on the second method as you included more derivatives?  How wide do you think the intervals could become?
