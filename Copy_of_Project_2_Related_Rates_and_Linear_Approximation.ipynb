# %% [markdown]
# <a href="https://colab.research.google.com/github/ryleemeyer/Linear_Algebra_Coading_projects/blob/main/Copy_of_Project_2_Related_Rates_and_Linear_Approximation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project 2:  Linear Approximation, Related Rates, Optimization
#
# For this project, you will solve the following two problems:
#
#   1.  Create linear and higher-order approximations for $y = ln(x)$.  Your models will be used to create various estimates of $y = ln(1+a)$.  You'll also make a guess a the actual value of $ln(1+a)$ based on your improvements in the estimate.
#
#   2.  Solve a related rates problem both algebraically and computationally.  You'll then adjust one of the quantities to see the impact on your results.  When working on this project, your results should be consistent with each other.
#
# One final question will be related to your preferences for using computation or algebra for solving problems.  Be sure to provide concrete examples of when you prefer to solve a problem algebraically or computationally.

# %% [markdown]
# # Project 2A:  Approximate $y = ln(x)$ near $x = 1$
#
# In this project, you will approximate the function
#
# $$  y = ln(x) $$
#
# using the best point, line, parabola, and third-degree polynomial.  The code is written in Desmos.  You'll be asked to provide a screenshot showing:
#
#   1.  The approximation with just a contant
#   2.  The approximation with just a line (using a derivative)
#   3.  The approximation with a quadratic (using 1st and 2nd derivatives)
#   4.  The approximation with a cubic (using 1st, 2nd, and 3rd derivatives)
#
# For this project, You'll also develop three methods for approximating
#
# $$  ln(1+a) $$
#
# for both positive and negative values of $a$ near 0.

# %%
desmosSheet1 = "https://www.desmos.com/calculator/phmfcgjnhh"
#  Copy the url above and paste into a separate browser window.
#  Then, make screen captures and paste the results into the cells below.
#  Uncomment these to put the Desmos page here:
#from IPython.display import IFrame
#IFrame(src=desmosSheet1, width=1200, height=575)

# %% [markdown]
# ## A - 1  Approximating the curve with just a constant:
#
# The approximation to $y = ln(x)$ is given by
#
# $$  y \approx ln(0) $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## A - 2  Approximating the curve with just a line (using a derivative):

# %% [markdown]
# ![Screen Shot 2022-03-17 at 1.53.59 PM.png](data:image/png;base64,...)<< Paste the image from Desmos here >>

# %% [markdown]
# ## A - 3  Approximating the curve with a quadratic (using a 1st and 2nd derivative):

# %% [markdown]
# ![Screen Shot 2022-03-17 at 1.56.08 PM.png](data:image/png;base64,...)<< Paste the image from Desmos here. >>

# %% [markdown]
# # Project 2B:  Related Rates problem
#
# In this project, you will determine the rate at which the water level is rising in a swimming pool.  You'll be asked to solve the problem both symbolically, using algebra, and computationally, using Sheets, Desmos, and Colab.  Your answers should agree.  At the end of the project, you'll discuss the advantage or disadvantage of each approach.
#
# ## Problem: Related Rates ##
#
# A rectangular swimming pool $15$ meters long and $8$ meters wide has a depth of $4$ meters at one end and $0.5$ meters at the other end.  On a bright sunny day, the water level is initially $3$ meters deep at the deep end.  An average college student has a volume of $84$ liters.  If the college students jump into the pool at a rate of one every $15 sec$, how quickly is the water level rising when the 6th college student enters the pool?
#
# [Note:   Assume that students stay in the pool and keep their heads, which have a volume of $9 $ liters, above water! ]
#
# [ Note 2:  $1$ liter is the same as $0.001$ cubic meters ]
#
# Part 1:  Determine the original volume of water in the pool.  Give the result in both Liters and cubic meters.
#
# Part 2:  Find an equation between the height of the water in the pool and the volume ( of water and bodies) in the pool.
#
# Part 3:  Solve the problem algebraically.  Your solution should include differentials, derivatives, and the appropriate evaluation.
#
# Part 4:  Create a table capturing the time, number of students and water in the pool, and the height of the water in the pool at a given time:
#
#   | time | # of students in pool |   Volume  | Water level |
#   |------|-----------------------|-----------|------------|
#   | 0 sec |        0             | 180,000   |    3 m     |
#   | 15 sec|        1             |180,000+75 |   63 m     |
#   | 30 sec|        2             |180,075+75 |  123 m     |
#   | 45 sec|        3             |180,150+75 |  183 m     |
#   | 60 sec|        4             |180,225+75 |  243 m     |
#   | 75 sec|        5             |180,300+75 |  303 m     |
#   | 90 sec|        6             |180,375+75 |  363 m     |
#   |120 sec|        7             |180,40+75  |  423 m     |
#
# Part 5:  Using your table, find the rate at which the water level is rising in meters per student.
#
# Part 6:  Water evaporation is fairly insignificant, losing about $0.25$ liters per minute.  Include this information into either your algebraic or computation solution.  What is the overall impact on the rate at which water is rising (in meters per student)?
#
#
# If you use Desmos or Colab for any of your work, be sure to take a screen shot and paste it into this Colab project below.  Write your answers and algebraic work in the packet.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# If you would like to use a Google Sheet, create one and paste the url into the cell below.
GoogleSheet_URL = ""
#from IPython.display import IFrame
#IFrame(src=GoogleSheet_URL, width=800, height=375)
